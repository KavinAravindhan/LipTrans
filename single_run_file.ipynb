# %%
import os
import cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv3D, LSTM, Dense, Dropout, Bidirectional, MaxPool3D, Activation, Reshape, SpatialDropout3D, BatchNormalization, TimeDistributed, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from typing import List

def load_data(path: str): 
    path = bytes.decode(path.numpy())
    #file_name = path.split('/')[-1].split('.')[0]
    # File name splitting for windows
    file_name = path.split('\\')[-1].split('.')[0]
    # video_path = os.path.join('data','s1',f'{file_name}.mpg')
    video_path = os.path.join('complete_data','s3',f'{file_name}.mpg')
    alignment_path = os.path.join('data','alignments','s1',f'{file_name}.align')
    frames = load_video(video_path) 
    # alignments = load_alignments(alignment_path)
    alignments=[]
    return frames, alignments

def load_video(path:str) -> List[float]: 
    print(path)
    cap = cv2.VideoCapture(path)
    frames = []
    for _ in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))): 
        ret, frame = cap.read()
        frame = tf.image.rgb_to_grayscale(frame)
        frames.append(frame[190:236,80:220,:])
    cap.release()
    
    mean = tf.math.reduce_mean(frames)
    std = tf.math.reduce_std(tf.cast(frames, tf.float32))
    return tf.cast((frames - mean), tf.float32) / std

def load_alignments(path:str) -> List[str]: 
    with open(path, 'r') as f: 
        lines = f.readlines() 
    tokens = []
    for line in lines:
        line = line.split()
        if line[2] != 'sil': 
            tokens = [*tokens,' ',line[2]]
    return char_to_num(tf.reshape(tf.strings.unicode_split(tokens, input_encoding='UTF-8'), (-1)))[1:]

vocab = [x for x in "abcdefghijklmnopqrstuvwxyz'?!123456789 "]
char_to_num = tf.keras.layers.StringLookup(vocabulary=vocab, oov_token="")
num_to_char = tf.keras.layers.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), oov_token="", invert=True
)

model = Sequential()
model.add(Conv3D(128, 3, input_shape=(75,46,140,1), padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1,2,2)))

model.add(Conv3D(256, 3, padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1,2,2)))

model.add(Conv3D(75, 3, padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1,2,2)))

model.add(TimeDistributed(Flatten()))

model.add(Bidirectional(LSTM(128, kernel_initializer='Orthogonal', return_sequences=True)))
model.add(Dropout(.5))

model.add(Bidirectional(LSTM(128, kernel_initializer='Orthogonal', return_sequences=True)))
model.add(Dropout(.5))

model.add(Dense(char_to_num.vocabulary_size()+1, kernel_initializer='he_normal', activation='softmax'))

### Compile the model

model.load_weights('models_100_e/checkpoint')

# %%
list_data = tf.data.Dataset.list_files('./complete_data/s3/*.mpg')
file_list = list_data.as_numpy_iterator()
fl=list(file_list)

# %%
for i in fl:
    # print(str(i.decode('utf-8')))
    # sample = load_data(tf.convert_to_tensor('.\\s2_pwaq2a.mpg'))
    sample = load_data(tf.convert_to_tensor(i))

    yhat = model.predict(tf.expand_dims(sample[0], axis=0))

    decoded = tf.keras.backend.ctc_decode(yhat, input_length=[75], greedy=True)[0][0].numpy()

    predicted = [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in decoded][0].numpy().decode('utf-8')

    print(i, " : ", predicted)
# Out:
# complete_data\s3\bwbn3a.mpg
# 1/1 [==============================] - 3s 3s/step
# b'.\\complete_data\\s3\\bwbn3a.mpg'  :  lay le in o ploeain
# complete_data\s3\prap3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prap3s.mpg'  :  set blue s nene sooon
# complete_data\s3\sgwj3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgwj3s.mpg'  :  place wree wit i ore psleain
# complete_data\s3\pgiq2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgiq2p.mpg'  :  lay blue in s seueve ageain
# complete_data\s3\lbbk2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbbk2n.mpg'  :  bin whee in g zore seasin
# complete_data\s3\srwi2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srwi2p.mpg'  :  lay blue ih i toure segeain
# complete_data\s3\prwj7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prwj7s.mpg'  :  lay blue si soe again
# complete_data\s3\srwu9s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srwu9s.mpg'  :  lay gle st soe seasin
# complete_data\s3\bbbz6n.mpg
# 1/1 [==============================] - 1s 992ms/step
# b'.\\complete_data\\s3\\bbbz6n.mpg'  :  place re in t seve sgean
# complete_data\s3\bwwh3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwwh3a.mpg'  :  sin blee in x sive again
# complete_data\s3\pbwj2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbwj2p.mpg'  :  lac ge ait la e inen seain
# complete_data\s3\lgbs7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgbs7a.mpg'  :  bin white in n nee soon
# complete_data\s3\swih6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swih6p.mpg'  :  bin blue bu s si noooin
# complete_data\s3\bgia1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgia1s.mpg'  :  bin ree in o again
# complete_data\s3\lrwl4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrwl4p.mpg'  :  lay blue i i sive seaisn
# complete_data\s3\lbwk6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbwk6n.mpg'  :  set gree it s sie soon
# complete_data\s3\bwwu1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwwu1a.mpg'  :  place blue bt s six pleasen
# complete_data\s3\bramzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bramzn.mpg'  :  spsla se sas se slgain
# complete_data\s3\lwbszp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwbszp.mpg'  :  bin iee in sixe seasn
# complete_data\s3\prwd2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prwd2n.mpg'  :  lay ree it i five sgain
# complete_data\s3\pbwc8p.mpg
# 1/1 [==============================] - 1s 999ms/step
# b'.\\complete_data\\s3\\pbwc8p.mpg'  :  place bluen by i s uee sagain
# complete_data\s3\srbu5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srbu5s.mpg'  :  bin bluen in i sie again
# complete_data\s3\srwizn.mpg
# 1/1 [==============================] - 1s 983ms/step
# b'.\\complete_data\\s3\\srwizn.mpg'  :  lay ge slt s s sene again
# complete_data\s3\lbwk8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbwk8p.mpg'  :  plac green in u seve sgoan
# complete_data\s3\sgib9a.mpg
# 1/1 [==============================] - 1s 959ms/step
# b'.\\complete_data\\s3\\sgib9a.mpg'  :  plac re in i ore pgeain
# complete_data\s3\srah5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srah5a.mpg'  :  lay ble it ie pgeain
# complete_data\s3\lwik7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwik7s.mpg'  :  plac white in z on sooin
# complete_data\s3\sgwj5a.mpg
# 1/1 [==============================] - 1s 977ms/step
# b'.\\complete_data\\s3\\sgwj5a.mpg'  :  lay blue an p sie plaie
# complete_data\s3\sbwh5s.mpg
# 1/1 [==============================] - 1s 987ms/step
# b'.\\complete_data\\s3\\sbwh5s.mpg'  :  place re sin u nene sgain
# complete_data\s3\lwws4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwws4p.mpg'  :  lace reen i sie psleain
# complete_data\s3\lrbl1a.mpg
# 1/1 [==============================] - 1s 965ms/step
# b'.\\complete_data\\s3\\lrbl1a.mpg'  :  lay lue i t se again
# complete_data\s3\pwaj5s.mpg
# 1/1 [==============================] - 1s 998ms/step
# b'.\\complete_data\\s3\\pwaj5s.mpg'  :  lay blue it si plain
# complete_data\s3\lwiy7a.mpg
# 1/1 [==============================] - 1s 982ms/step
# b'.\\complete_data\\s3\\lwiy7a.mpg'  :  lay ble sn sinen gan
# complete_data\s3\sbig5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbig5a.mpg'  :  bin gree in c zeo pleaisn
# complete_data\s3\pbbpzn.mpg
# 1/1 [==============================] - 1s 990ms/step
# b'.\\complete_data\\s3\\pbbpzn.mpg'  :  place gre it s sive again
# complete_data\s3\bbws6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbws6n.mpg'  :  bin wree in z zove paeain
# complete_data\s3\lwiy6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwiy6p.mpg'  :  set blue st si plase
# complete_data\s3\lbbq9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbbq9a.mpg'  :  lay green in nie pleasien
# complete_data\s3\lgws8n.mpg
# 1/1 [==============================] - 1s 975ms/step
# b'.\\complete_data\\s3\\lgws8n.mpg'  :  sen brue sn t sou pseain
# complete_data\s3\pgix6p.mpg
# 1/1 [==============================] - 1s 970ms/step
# b'.\\complete_data\\s3\\pgix6p.mpg'  :  place ree inh sesive again
# complete_data\s3\swwp1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swwp1s.mpg'  :  lace le at s sie ageain
# complete_data\s3\pric2p.mpg
# 1/1 [==============================] - 1s 972ms/step
# b'.\\complete_data\\s3\\pric2p.mpg'  :  bin brue in sesee sgain
# complete_data\s3\pbii1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbii1a.mpg'  :  set gre in s sie pleasen
# complete_data\s3\pwax5a.mpg
# 1/1 [==============================] - 1s 995ms/step
# b'.\\complete_data\\s3\\pwax5a.mpg'  :  let redn in i six pleaien
# complete_data\s3\pbbp2p.mpg
# 1/1 [==============================] - 1s 976ms/step
# b'.\\complete_data\\s3\\pbbp2p.mpg'  :  place re win s soue aleain
# complete_data\s3\prwx6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prwx6p.mpg'  :  place red in sie again
# complete_data\s3\lrid7s.mpg
# 1/1 [==============================] - 1s 992ms/step
# b'.\\complete_data\\s3\\lrid7s.mpg'  :  bin red it u seie sooon
# complete_data\s3\sran6n.mpg
# 1/1 [==============================] - 1s 967ms/step
# b'.\\complete_data\\s3\\sran6n.mpg'  :  plac gree it t five again
# complete_data\s3\brif4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brif4p.mpg'  :  set re in t five again
# complete_data\s3\pbwp6p.mpg
# 1/1 [==============================] - 1s 990ms/step
# b'.\\complete_data\\s3\\pbwp6p.mpg'  :  bin blue in ove sgain
# complete_data\s3\bbbf6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbbf6p.mpg'  :  bin white it o oine aoain
# complete_data\s3\pbwj1s.mpg
# 1/1 [==============================] - 1s 976ms/step
# b'.\\complete_data\\s3\\pbwj1s.mpg'  :  bin whee it s sive sgeasn
# complete_data\s3\pbwx1a.mpg
# 1/1 [==============================] - 1s 982ms/step
# b'.\\complete_data\\s3\\pbwx1a.mpg'  :  bin whie in o zeore pleaien
# complete_data\s3\lwws3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwws3s.mpg'  :  plac gre win sio poan
# complete_data\s3\srah4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srah4p.mpg'  :  lay white n five plain
# complete_data\s3\sgiu9s.mpg
# 1/1 [==============================] - 1s 941ms/step
# b'.\\complete_data\\s3\\sgiu9s.mpg'  :  set gee in ie soaon
# complete_data\s3\bwbt6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwbt6p.mpg'  :  plac bree it sie ageain
# complete_data\s3\sgio7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgio7a.mpg'  :  lay ge in s sie pleasen
# complete_data\s3\pbiu6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbiu6n.mpg'  :  lea re ani n niven again
# complete_data\s3\lgwg3a.mpg
# 1/1 [==============================] - 1s 980ms/step
# b'.\\complete_data\\s3\\lgwg3a.mpg'  :  set blue in eie seasn
# complete_data\s3\bwam7s.mpg
# 1/1 [==============================] - 1s 999ms/step
# b'.\\complete_data\\s3\\bwam7s.mpg'  :  la reed ini i sive soon
# complete_data\s3\lrwz3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrwz3a.mpg'  :  playe blue in sie ageain
# complete_data\s3\pwij2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwij2p.mpg'  :  place re it s soee sleasn
# complete_data\s3\pwic7s.mpg
# 1/1 [==============================] - 1s 954ms/step
# b'.\\complete_data\\s3\\pwic7s.mpg'  :  bin white it u sive soon
# complete_data\s3\sban2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sban2p.mpg'  :  plac gee it x sixe pagease
# complete_data\s3\lbwe4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbwe4p.mpg'  :  set gree in s siwor sgeasin
# complete_data\s3\pgby2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgby2n.mpg'  :  bin gree in s siue please
# complete_data\s3\swib1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swib1s.mpg'  :  ln blue t z o plasene
# complete_data\s3\bram1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bram1s.mpg'  :  sen re in oie ageain
# complete_data\s3\bgat7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgat7s.mpg'  :  place bre by u sio please
# complete_data\s3\pbiu8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbiu8p.mpg'  :  place white in t zo sleain
# complete_data\s3\pgwy8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgwy8p.mpg'  :  laye gle it i six please
# complete_data\s3\pbiu9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbiu9a.mpg'  :  place green it i fivee soin
# complete_data\s3\bris2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bris2p.mpg'  :  set gree in x six pleaien
# complete_data\s3\bgwb2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgwb2n.mpg'  :  bin re ih sive agon
# complete_data\s3\bbal6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbal6p.mpg'  :  plac green it i ix please
# complete_data\s3\pbbp3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbbp3a.mpg'  :  lac white at ine sgoon
# complete_data\s3\sgbp5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgbp5a.mpg'  :  place green it x s seve agasin
# complete_data\s3\lwazzp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwazzp.mpg'  :  lay brue in s noo soaon
# complete_data\s3\lriq4n.mpg
# 1/1 [==============================] - 1s 990ms/step
# b'.\\complete_data\\s3\\lriq4n.mpg'  :  lay white bn fie poloease
# complete_data\s3\srit9a.mpg
# 1/1 [==============================] - 1s 976ms/step
# b'.\\complete_data\\s3\\srit9a.mpg'  :  lay ble sit s nine pleasen
# complete_data\s3\lgaz7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgaz7a.mpg'  :  bin whie n i six pleasen
# complete_data\s3\prbp8p.mpg
# 1/1 [==============================] - 1s 976ms/step
# b'.\\complete_data\\s3\\prbp8p.mpg'  :  la ble ain i i i son
# complete_data\s3\lrby7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrby7s.mpg'  :  plac bleen an sie again
# complete_data\s3\lbby2p.mpg
# 1/1 [==============================] - 1s 952ms/step
# b'.\\complete_data\\s3\\lbby2p.mpg'  :  plac ge it p sese sgain
# complete_data\s3\prip1a.mpg
# 1/1 [==============================] - 1s 994ms/step
# b'.\\complete_data\\s3\\prip1a.mpg'  :  place bleen with x sese seasn
# complete_data\s3\sgbc6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgbc6p.mpg'  :  plac re in ix six pleasise
# complete_data\s3\sgwj4p.mpg
# 1/1 [==============================] - 1s 995ms/step
# b'.\\complete_data\\s3\\sgwj4p.mpg'  :  place blue in iue seain
# complete_data\s3\pgid2n.mpg
# 1/1 [==============================] - 1s 948ms/step
# b'.\\complete_data\\s3\\pgid2n.mpg'  :  lay bree in s sive ageain
# complete_data\s3\swiu4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swiu4p.mpg'  :  sin blue in sine ageain
# complete_data\s3\lwwm1a.mpg
# 1/1 [==============================] - 1s 981ms/step
# b'.\\complete_data\\s3\\lwwm1a.mpg'  :  play blue bn oue pleasin
# complete_data\s3\prai9s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prai9s.mpg'  :  lace gre it nine again
# complete_data\s3\bgan2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgan2n.mpg'  :  play blue i seve again
# complete_data\s3\sbanzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbanzn.mpg'  :  lay blue in v sivi sooon
# complete_data\s3\lgwg1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgwg1s.mpg'  :  plac green in s sixe pleasine
# complete_data\s3\pbbi8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbbi8p.mpg'  :  lay re in i hixt pleain
# complete_data\s3\bbiy9s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbiy9s.mpg'  :  bin gree in c zou please
# complete_data\s3\sbit2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbit2p.mpg'  :  la gle nin finene sgain
# complete_data\s3\pgwe5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgwe5s.mpg'  :  lay ble nin t tixe please
# complete_data\s3\pbbv5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbbv5s.mpg'  :  set blee in s iue sageain
# complete_data\s3\sria5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sria5s.mpg'  :  plac green in i tire again
# complete_data\s3\prbj5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prbj5a.mpg'  :  bin whie in z zore sogain
# complete_data\s3\lrwzzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrwzzn.mpg'  :  place blue in c z zive again
# complete_data\s3\brwm8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brwm8n.mpg'  :  place gre in i in ngoain
# complete_data\s3\bwag5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwag5a.mpg'  :  place blue in z oe oaon
# complete_data\s3\bwwn4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwwn4n.mpg'  :  laye blue i i ixe sagain
# complete_data\s3\briz4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\briz4n.mpg'  :  set whee in i ive again
# complete_data\s3\swwc3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swwc3s.mpg'  :  lay ble it e aganin
# complete_data\s3\swwv6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swwv6p.mpg'  :  sin gree in sie again
# complete_data\s3\brwt4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brwt4p.mpg'  :  set gree in t sinene again
# complete_data\s3\bgwu7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgwu7a.mpg'  :  place green in u seree again
# complete_data\s3\srwb7s.mpg
# 1/1 [==============================] - 1s 964ms/step
# b'.\\complete_data\\s3\\srwb7s.mpg'  :  set blue sn s seve again
# complete_data\s3\lbax7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbax7s.mpg'  :  bin red bth s sive again
# complete_data\s3\bwis8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwis8p.mpg'  :  lay gre ai ix se seain
# complete_data\s3\bbir7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbir7a.mpg'  :  place le btit u sese seasn
# complete_data\s3\pgiq1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgiq1s.mpg'  :  lay blue s so paeain
# complete_data\s3\brbs9s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brbs9s.mpg'  :  place lee bsi s ie again
# complete_data\s3\swin8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swin8n.mpg'  :  lay green inin sine pleasin
# complete_data\s3\pbwc9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbwc9a.mpg'  :  lace gre ait sie sleasen
# complete_data\s3\pgiq3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgiq3a.mpg'  :  ln green bn y tire seain
# complete_data\s3\swbc1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swbc1a.mpg'  :  place glue it p se aleasenin n so
# complete_data\s3\bris1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bris1s.mpg'  :  place blue in eoue sgain
# complete_data\s3\bwim2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwim2n.mpg'  :  set gre in n ninen gain
# complete_data\s3\lbwe2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbwe2n.mpg'  :  bin green wit s siux please
# complete_data\s3\prwj9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prwj9a.mpg'  :  lay rle in s s six please
# complete_data\s3\sbag6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbag6n.mpg'  :  set blee in i six psleasin
# complete_data\s3\bwwh2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwwh2p.mpg'  :  place white in x sixe pleaisen
# complete_data\s3\sgai6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgai6p.mpg'  :  lace green it v sevene again
# complete_data\s3\lwie5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwie5a.mpg'  :  place gee ih i ix pleasie
# complete_data\s3\pgbezn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgbezn.mpg'  :  lay ble ain t e seain
# complete_data\s3\pgbk7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgbk7a.mpg'  :  place ble s s se again
# complete_data\s3\swwi8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swwi8p.mpg'  :  set ge sin sie gleasene
# complete_data\s3\prwx5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prwx5s.mpg'  :  plac ree in i sre again
# complete_data\s3\pgwe7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgwe7a.mpg'  :  bln blue in u s sive pleaien
# complete_data\s3\lrik1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrik1s.mpg'  :  plae blee it ivee sgain
# complete_data\s3\pwij3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwij3a.mpg'  :  laye blue bt seseve again
# complete_data\s3\pbab8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbab8n.mpg'  :  plac brue bn s sin sgain
# complete_data\s3\prav9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prav9a.mpg'  :  bin blue in i ive sgeain
# complete_data\s3\pbbv7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbbv7a.mpg'  :  set lue bn inoe seain
# complete_data\s3\bras6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bras6p.mpg'  :  bin re iy ie again
# complete_data\s3\swwpzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swwpzn.mpg'  :  lac ge en s nin soin
# complete_data\s3\bgit4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgit4p.mpg'  :  place rue in n nie again
# complete_data\s3\bwba2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwba2n.mpg'  :  set red in i ige again
# complete_data\s3\lgaf2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgaf2n.mpg'  :  lay gree it oee again
# complete_data\s3\pbwjzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbwjzn.mpg'  :  set blue it u sone sgoin
# complete_data\s3\bbaz5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbaz5a.mpg'  :  lety gree in s sixe pleasen
# complete_data\s3\bram3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bram3a.mpg'  :  lay blue bi ive again
# complete_data\s3\bgba9s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgba9s.mpg'  :  place rie bn c oe pageain
# complete_data\s3\pwbd5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwbd5s.mpg'  :  bin blue st ps six pleasen
# complete_data\s3\swab6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swab6p.mpg'  :  lay lee it see sgain
# complete_data\s3\lbwy5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbwy5s.mpg'  :  lay gre it xs sie again
# complete_data\s3\lbij4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbij4n.mpg'  :  plac gren i foue soasn
# complete_data\s3\srwb8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srwb8p.mpg'  :  bin brue in sie sgain
# complete_data\s3\pwij1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwij1s.mpg'  :  place green it s seve again
# complete_data\s3\bbir6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbir6p.mpg'  :  lay blue it p six pleain
# complete_data\s3\prbc9s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prbc9s.mpg'  :  bin white in o zo son
# complete_data\s3\prbx3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prbx3a.mpg'  :  lay blue ain is sixe paleaisi
# complete_data\s3\srig8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srig8n.mpg'  :  set le it sie alease
# complete_data\s3\srin4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srin4p.mpg'  :  lay blue an sie leain
# complete_data\s3\prbx1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prbx1s.mpg'  :  plac blee it s sivx sleain
# complete_data\s3\srwv1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srwv1a.mpg'  :  lay re sn s se plase
# complete_data\s3\prbp9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prbp9a.mpg'  :  place glre it six please
# complete_data\s3\pwwe1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwwe1a.mpg'  :  set re in i in again
# complete_data\s3\swbv3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swbv3a.mpg'  :  plac blue sn i sin eain
# complete_data\s3\lwir1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwir1s.mpg'  :  plac red wt u sevee sgeasin
# complete_data\s3\pwwezp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwwezp.mpg'  :  lay blue bt i ie sagain
# complete_data\s3\sria6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sria6p.mpg'  :  place white in v feoee sgeain
# complete_data\s3\lrwe8n.mpg
# 1/1 [==============================] - 1s 992ms/step
# b'.\\complete_data\\s3\\lrwe8n.mpg'  :  plac blue in zerer please
# complete_data\s3\lbwy4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbwy4n.mpg'  :  la een in ninen again
# complete_data\s3\swbczp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swbczp.mpg'  :  place gree an v zire sageain
# complete_data\s3\swiu2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swiu2n.mpg'  :   se
# complete_data\s3\lrwl2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrwl2n.mpg'  :  place green bn i thie alain
# complete_data\s3\lwws5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwws5a.mpg'  :  plac le p s sene soaon
# complete_data\s3\pbwc7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbwc7s.mpg'  :  bin whie in z zeo again
# complete_data\s3\lwar5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwar5s.mpg'  :  la gre sn se slean
# complete_data\s3\pgad7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgad7s.mpg'  :  bin wree it o one sgoin
# complete_data\s3\bgaa6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgaa6p.mpg'  :  place blue ith t oe agon
# complete_data\s3\lwwz8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwwz8p.mpg'  :  place blue in s s sine seain
# complete_data\s3\lrwr9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrwr9a.mpg'  :  lay wree in m s seve again
# complete_data\s3\bwbt5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwbt5s.mpg'  :  laye lue it s s sinen sgan
# complete_data\s3\srbb3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srbb3s.mpg'  :  lay ge at e s se again
# complete_data\s3\sbba8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbba8p.mpg'  :  lay ree in i sie ageain
# complete_data\s3\sran7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sran7s.mpg'  :  sen blue in x sie aleasin
# complete_data\s3\brbg1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brbg1s.mpg'  :  bin blue in soiue pageain
# complete_data\s3\prbc8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prbc8n.mpg'  :  place gre bn sive again
# complete_data\s3\srwo7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srwo7a.mpg'  :  lay ble slit l ise sain
# complete_data\s3\lray3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lray3s.mpg'  :  lace bluen in six pleain
# complete_data\s3\swwv5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swwv5s.mpg'  :  set gree in n ie again
# complete_data\s3\bbar8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbar8n.mpg'  :  playe bleen bt sive again
# complete_data\s3\bgbn7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgbn7s.mpg'  :  bin gree at sive soon
# complete_data\s3\sgwx3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgwx3a.mpg'  :  bin blue in u eio palain
# complete_data\s3\pbbv6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbbv6p.mpg'  :  sen gre in nine again
# complete_data\s3\sbbn7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbbn7a.mpg'  :  pla be rie wit s niue pgeain
# complete_data\s3\bwwt8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwwt8n.mpg'  :  place blue in z zeoen sgain
# complete_data\s3\pgbk4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgbk4n.mpg'  :  bln blue bn u siv again
# complete_data\s3\swau6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swau6n.mpg'  :  blnc blue ith p senene sgain
# complete_data\s3\lwik8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwik8p.mpg'  :  play red it eove asgain
# complete_data\s3\swih7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swih7a.mpg'  :  place whie it z or peeain
# complete_data\s3\pgak1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgak1s.mpg'  :  lace gleen in ixe sleasisn
# complete_data\s3\bwis6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwis6n.mpg'  :  la ge n o s nee soon
# complete_data\s3\pgwk8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgwk8n.mpg'  :  place bluen it t s seve sgain
# complete_data\s3\pwbq5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwbq5a.mpg'  :  plac ree ih i ie ageasin
# complete_data\s3\lgil2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgil2n.mpg'  :  place green iy nine segeain
# complete_data\s3\lrby6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrby6n.mpg'  :  lay red ai nine sgain
# complete_data\s3\prwj8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prwj8p.mpg'  :  lay blue it sie again
# complete_data\s3\lrix8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrix8n.mpg'  :  play red wit fie again
# complete_data\s3\swib2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swib2p.mpg'  :  plac blue in p psen easenen
# complete_data\s3\bwim4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwim4p.mpg'  :  lay gre in s se seains
# complete_data\s3\prai8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prai8n.mpg'  :  place wrue in z z ove plasene
# complete_data\s3\pwbq2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwbq2n.mpg'  :  set blue ait u eive again
# complete_data\s3\sbbhzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbbhzn.mpg'  :  lay blue it f fie sgain
# complete_data\s3\priczn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\priczn.mpg'  :  set re in sive again
# complete_data\s3\pbih9s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbih9s.mpg'  :  lay blue in ive sgin
# complete_data\s3\bwag3s.mpg
# 1/1 [==============================] - 1s 994ms/step
# b'.\\complete_data\\s3\\bwag3s.mpg'  :  set gree in i in soon
# complete_data\s3\lrak7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrak7a.mpg'  :  place blue in z onen soon
# complete_data\s3\pgbe2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgbe2p.mpg'  :  place gree ith r sine soaon
# complete_data\s3\bgwb5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgwb5a.mpg'  :  place green in t ie again
# complete_data\s3\lgir9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgir9a.mpg'  :  bin blue in se sleasen
# complete_data\s3\lgil3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgil3s.mpg'  :  place le set s s e sgeain
# complete_data\s3\bris3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bris3a.mpg'  :  sen green it v sino psleain
# complete_data\s3\sbbn4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbbn4n.mpg'  :  place gee in n ixe sleain
# complete_data\s3\bbizzp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbizzp.mpg'  :  place lue in evive again
# complete_data\s3\srbu6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srbu6p.mpg'  :  bin breen in i six sleain
# complete_data\s3\pwixzp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwixzp.mpg'  :  place blue in z zere sgain
# complete_data\s3\pgwlzp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgwlzp.mpg'  :  lay lue ith u s seve again
# complete_data\s3\srwb9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srwb9a.mpg'  :  place bleen bt s siou please
# complete_data\s3\lrak6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrak6p.mpg'  :  lace wree in i seveve again
# complete_data\s3\lgal8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgal8p.mpg'  :  bin bred bn six please
# complete_data\s3\swbi5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swbi5a.mpg'  :  lay green it s s sive sageain
# complete_data\s3\lwwf6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwwf6p.mpg'  :  plac blee in se asgain
# complete_data\s3\bril8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bril8p.mpg'  :  place lue it sito please
# complete_data\s3\bgat9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgat9a.mpg'  :  sin ree wbt s ie soain
# complete_data\s3\sbim6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbim6n.mpg'  :  place whie in z oen again
# complete_data\s3\sbwu5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sbwu5a.mpg'  :  plac re win seve soon
# complete_data\s3\swwc2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swwc2n.mpg'  :  lae blue wit p se sleasn
# complete_data\s3\bwbg9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwbg9a.mpg'  :  plac reree sin nine again
# complete_data\s3\bgig7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgig7a.mpg'  :  set green in i sie aleasese
# complete_data\s3\srbh8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\srbh8p.mpg'  :  pln blue in i sior please
# complete_data\s3\pwbk1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwbk1a.mpg'  :  sea re sit s sve again
# complete_data\s3\prii7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prii7a.mpg'  :  set re s s six pleaien
# complete_data\s3\pbwxzp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbwxzp.mpg'  :  bin whue in o oe seain
# complete_data\s3\lgaz5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgaz5s.mpg'  :  bln blue in oe soain
# complete_data\s3\swiu5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swiu5a.mpg'  :  sea se sit s s e sein
# complete_data\s3\lwwl8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwwl8n.mpg'  :  place blue bn six please
# complete_data\s3\sgwp7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgwp7s.mpg'  :  plae green in x sixe aeain
# complete_data\s3\bgbn6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgbn6n.mpg'  :  lay gre ain n is ie sgeainin sle
# complete_data\s3\pbai3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbai3s.mpg'  :  lay blue is i ih pageain
# complete_data\s3\brif3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brif3s.mpg'  :  sin ghite in io poeain
# complete_data\s3\lgwgzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgwgzn.mpg'  :  bin green in n nine again
# complete_data\s3\lwae7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwae7s.mpg'  :  place whie in z oe again
# complete_data\s3\pwwq6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwwq6n.mpg'  :  bin whue bs s seseve sgeasn
# complete_data\s3\lgwtzp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgwtzp.mpg'  :  set gree in ine again
# complete_data\s3\brwg5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brwg5s.mpg'  :  place gree with q seive please
# complete_data\s3\pbwc6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbwc6n.mpg'  :  bin gree in seve soon
# complete_data\s3\swbb8n.mpg
# 1/1 [==============================] - 1s 977ms/step
# b'.\\complete_data\\s3\\swbb8n.mpg'  :  lay le ith s se pleain
# complete_data\s3\bgbn9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgbn9a.mpg'  :  s se ne asgain
# complete_data\s3\braz8n.mpg
# 1/1 [==============================] - 1s 992ms/step
# b'.\\complete_data\\s3\\braz8n.mpg'  :  bin blee it z oe sgeain
# complete_data\s3\bgit5a.mpg
# 1/1 [==============================] - 1s 998ms/step
# b'.\\complete_data\\s3\\bgit5a.mpg'  :  bin green it t seve sgoin
# complete_data\s3\lriq6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lriq6p.mpg'  :  lan lre iy none sgooin
# complete_data\s3\lwar7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwar7a.mpg'  :  lay green ain sie sgeain
# complete_data\s3\prav7s.mpg
# 1/1 [==============================] - 1s 996ms/step
# b'.\\complete_data\\s3\\prav7s.mpg'  :  place gre with n ninene soan
# complete_data\s3\bbaz4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbaz4p.mpg'  :  la green bt p sesee again
# complete_data\s3\lrbr4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrbr4p.mpg'  :  play blue wt u sive again
# complete_data\s3\lbbk3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbbk3s.mpg'  :  place rgen in teree again
# complete_data\s3\lgbm1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgbm1s.mpg'  :  lay brued by u ue again
# complete_data\s3\lrikzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrikzn.mpg'  :  place gree iy sevee again
# complete_data\s3\sgbp3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgbp3s.mpg'  :  bin red in s s sive sgain
# complete_data\s3\lbid3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbid3a.mpg'  :  place bue in sivex pleasene
# complete_data\s3\bbwm3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbwm3s.mpg'  :  set ble uin sie sgasin
# complete_data\s3\brbt1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brbt1a.mpg'  :  plac blue bp s seie pleasen
# complete_data\s3\pgwr2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgwr2n.mpg'  :  sen green in enee again
# complete_data\s3\lgwt1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgwt1a.mpg'  :  bin green wih sive please
# complete_data\s3\swab5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swab5s.mpg'  :  la blue in i foue sgain
# complete_data\s3\swwv4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swwv4n.mpg'  :  bin blue it s sie pleasen
# complete_data\s3\lray5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lray5a.mpg'  :  plac bleen in s s sie sagaien
# complete_data\s3\lrwfzp.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrwfzp.mpg'  :  plac blue in s sioix plain
# complete_data\s3\bbafzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbafzn.mpg'  :  laye gleen by five again
# complete_data\s3\lrak4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lrak4n.mpg'  :  bin whie in o o soon
# complete_data\s3\brbm4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brbm4n.mpg'  :  place ble sin sie sageain
# complete_data\s3\bgig6p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgig6p.mpg'  :  place blue by seve sooin
# complete_data\s3\lbaj9s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbaj9s.mpg'  :  lac white in n five again
# complete_data\s3\swab7a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swab7a.mpg'  :  bin ge si sene aeain
# complete_data\s3\swau8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swau8p.mpg'  :  sety le s s sene sgain
# complete_data\s3\bgan5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bgan5a.mpg'  :  lay blue sn six please
# complete_data\s3\lwie4p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lwie4p.mpg'  :  bin blue by z o pleasene
# complete_data\s3\swbo8p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swbo8p.mpg'  :  lay blue it sie again
# complete_data\s3\pbwj3a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pbwj3a.mpg'  :  place blue in c z oe ageain
# complete_data\s3\lbix2n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbix2n.mpg'  :  place green it v s fix pleain
# complete_data\s3\bwwh1s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwwh1s.mpg'  :  sea e ge sit p se seasin
# complete_data\s3\lbax6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbax6n.mpg'  :  lay le in bs sine enen sgain
# complete_data\s3\srwo5s.mpg
# 1/1 [==============================] - 1s 983ms/step
# b'.\\complete_data\\s3\\srwo5s.mpg'  :  lay blue at i ie aegeain
# complete_data\s3\prbp6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\prbp6n.mpg'  :  place blue it p seveve again
# complete_data\s3\swbo9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\swbo9a.mpg'  :  bin bree in i sio pleasin
# complete_data\s3\brif5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\brif5a.mpg'  :  place ge ith u se sgain
# complete_data\s3\bbbz7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bbbz7s.mpg'  :  place blue it sive again
# complete_data\s3\bwam9a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\bwam9a.mpg'  :  bin blue an i soe palgain
# complete_data\s3\pwwyzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwwyzn.mpg'  :  bin blue ith is ie sgeain
# complete_data\s3\sgbj1a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\sgbj1a.mpg'  :  bin white it o oue soon
# complete_data\s3\lrwr6n.mpg
# 1/1 [==============================] - 1s 989ms/step
# b'.\\complete_data\\s3\\lrwr6n.mpg'  :  set ren in n nine gain
# complete_data\s3\lbbd8n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbbd8n.mpg'  :  lay bre at eveve again
# complete_data\s3\pwad2p.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwad2p.mpg'  :  place green in i sixe sleasn
# complete_data\s3\pgij6n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pgij6n.mpg'  :  bla brue it u sive again
# complete_data\s3\lbad5s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbad5s.mpg'  :  set gre in i ie aoaien
# complete_data\s3\pwadzn.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\pwadzn.mpg'  :  pla re in i in algain
# complete_data\s3\lgaz4n.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lgaz4n.mpg'  :  laye ge th sive sgain
# complete_data\s3\lbbq7s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s3\\lbbq7s.mpg'  :  place greed in tere agasen
# complete_data\s3\brbm5s.mpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 6
#       1 for i in fl:
#       2     # print(str(i.decode('utf-8')))
#       3     # sample = load_data(tf.convert_to_tensor('.\\s2_pwaq2a.mpg'))
#       4     sample = load_data(tf.convert_to_tensor(i))
# ----> 6     yhat = model.predict(tf.expand_dims(sample[0], axis=0))
#       8     decoded = tf.keras.backend.ctc_decode(yhat, input_length=[75], greedy=True)[0][0].numpy()
#      10     predicted = [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in decoded][0].numpy().decode('utf-8')
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\keras\engine\training.py:2253, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2251 for step in data_handler.steps():
#    2252     callbacks.on_predict_batch_begin(step)
# -> 2253     tmp_batch_outputs = self.predict_function(iterator)
#    2254     if data_handler.should_sync:
#    2255         context.async_wait()
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
print('~'*100, 'PREDICTIONS')
predicted = [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in decoded][0].numpy().decode('utf-8')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ PREDICTIONS
# 'set green it r seve sgin'

# %%
model.reset_states()

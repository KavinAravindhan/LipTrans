# %%
import os
import cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv3D, LSTM, Dense, Dropout, Bidirectional, MaxPool3D, Activation, Reshape, SpatialDropout3D, BatchNormalization, TimeDistributed, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from typing import List

def load_data(path: str): 
    path = bytes.decode(path.numpy())
    #file_name = path.split('/')[-1].split('.')[0]
    # File name splitting for windows
    file_name = path.split('\\')[-1].split('.')[0]
    # video_path = os.path.join('data','s1',f'{file_name}.mpg')
    video_path = os.path.join('complete_data','s5',f'{file_name}.mpg')
    alignment_path = os.path.join('complete_data','alignments','s6',f'{file_name}.align')
    frames = load_video(video_path) 
    alignments = load_alignments(alignment_path)
    # alignments=[]
    return frames, alignments

def load_video(path:str) -> List[float]: 
    print(path)
    cap = cv2.VideoCapture(path)
    frames = []
    for _ in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))): 
        ret, frame = cap.read()
        frame = tf.image.rgb_to_grayscale(frame)
        frames.append(frame[190:236,80:220,:])
    cap.release()
    
    mean = tf.math.reduce_mean(frames)
    std = tf.math.reduce_std(tf.cast(frames, tf.float32))
    return tf.cast((frames - mean), tf.float32) / std

def load_alignments(path:str) -> List[str]: 
    with open(path, 'r') as f: 
        lines = f.readlines() 
    tokens = []
    for line in lines:
        line = line.split()
        if line[2] != 'sil': 
            tokens = [*tokens,' ',line[2]]
    return char_to_num(tf.reshape(tf.strings.unicode_split(tokens, input_encoding='UTF-8'), (-1)))[1:]

vocab = [x for x in "abcdefghijklmnopqrstuvwxyz'?!123456789 "]
char_to_num = tf.keras.layers.StringLookup(vocabulary=vocab, oov_token="")
num_to_char = tf.keras.layers.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), oov_token="", invert=True
)

model = Sequential()
model.add(Conv3D(128, 3, input_shape=(75,46,140,1), padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1,2,2)))

model.add(Conv3D(256, 3, padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1,2,2)))

model.add(Conv3D(75, 3, padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1,2,2)))

model.add(TimeDistributed(Flatten()))

model.add(Bidirectional(LSTM(128, kernel_initializer='Orthogonal', return_sequences=True)))
model.add(Dropout(.5))

model.add(Bidirectional(LSTM(128, kernel_initializer='Orthogonal', return_sequences=True)))
model.add(Dropout(.5))

model.add(Dense(char_to_num.vocabulary_size()+1, kernel_initializer='he_normal', activation='softmax'))

### Compile the model

model.load_weights('models_100_e/checkpoint')

# %%
list_data = tf.data.Dataset.list_files('./complete_data/s5/*.mpg')
file_list = list_data.as_numpy_iterator()
fl=list(file_list)

# %%
def word_accuracy_percentage(reference, hypothesis):
    reference_words = reference.split()
    hypothesis_words = hypothesis.split()
    correct_words = sum(1 for ref, hyp in zip(reference_words, hypothesis_words) if ref == hyp)
    total_words = len(reference_words)
    accuracy = (correct_words / total_words) * 100
    return accuracy
# print(word_accuracy_percentage(real_text, predicted_text))
for i in fl:
    # print(str(i.decode('utf-8')))
    # sample = load_data(tf.convert_to_tensor('.\\s2_pwaq2a.mpg'))
    sample = load_data(tf.convert_to_tensor(i))

    yhat = model.predict(tf.expand_dims(sample[0], axis=0))

    decoded = tf.keras.backend.ctc_decode(yhat, input_length=[75], greedy=True)[0][0].numpy()

    predicted = [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in decoded][0].numpy().decode('utf-8')
    real_text = [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in [sample[1]]][0].numpy().decode('utf-8')
    [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in [sample[1]]]

    if word_accuracy_percentage(real_text, predicted) >= 49.0 :
        print(i, " : ", predicted," : ",real_text," : ",word_accuracy_percentage(real_text, predicted))
# Out:
# complete_data\s5\pgwy4n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lgar8n.mpg
# 1/1 [==============================] - 1s 813ms/step
# complete_data\s5\prac5a.mpg
# 1/1 [==============================] - 1s 838ms/step
# complete_data\s5\pbbpzp.mpg
# 1/1 [==============================] - 1s 825ms/step
# complete_data\s5\lwae4n.mpg
# 1/1 [==============================] - 1s 797ms/step
# complete_data\s5\lwws1s.mpg
# 1/1 [==============================] - 1s 861ms/step
# complete_data\s5\pwadzp.mpg
# 1/1 [==============================] - 1s 906ms/step
# complete_data\s5\srwh9s.mpg
# 1/1 [==============================] - 1s 943ms/step
# complete_data\s5\prbx1a.mpg
# 1/1 [==============================] - 1s 834ms/step
# complete_data\s5\sgwjzn.mpg
# 1/1 [==============================] - 1s 922ms/step
# complete_data\s5\lrid5s.mpg
# 1/1 [==============================] - 1s 929ms/step
# complete_data\s5\prap2p.mpg
# 1/1 [==============================] - 1s 954ms/step
# complete_data\s5\pwwd9a.mpg
# 1/1 [==============================] - 1s 855ms/step
# complete_data\s5\pbab6n.mpg
# 1/1 [==============================] - 1s 954ms/step
# complete_data\s5\lgil3a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbig3a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bbbz5s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bwiz8n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\prwj4n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sgbv7a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bbar7s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bram1a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pwaxzn.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lgbs3s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bwat1a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lrae1a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lbbq4n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\srwizp.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\priv1s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bbaz2p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bbwz8n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbbn5a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbim6p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbwa9s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbit1a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lwbr7s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pgbk2n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sraa9a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bbie6p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbbn2n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pgij6p.mpg
# 1/1 [==============================] - 1s 828ms/step
# complete_data\s5\bgiazp.mpg
# 1/1 [==============================] - 1s 825ms/step
# complete_data\s5\sbag6p.mpg
# 1/1 [==============================] - 1s 838ms/step
# complete_data\s5\lbix3a.mpg
# 1/1 [==============================] - 1s 872ms/step
# complete_data\s5\bbwf8p.mpg
# 1/1 [==============================] - 1s 864ms/step
# complete_data\s5\lbwy3s.mpg
# 1/1 [==============================] - 1s 857ms/step
# complete_data\s5\lwar4p.mpg
# 1/1 [==============================] - 1s 833ms/step
# complete_data\s5\srbu2n.mpg
# 1/1 [==============================] - 1s 832ms/step
# complete_data\s5\brbs6n.mpg
# 1/1 [==============================] - 1s 798ms/step
# complete_data\s5\sgab8n.mpg
# 1/1 [==============================] - 1s 831ms/step
# complete_data\s5\bbws4n.mpg
# 1/1 [==============================] - 1s 794ms/step
# complete_data\s5\lgbz8p.mpg
# 1/1 [==============================] - 1s 835ms/step
# complete_data\s5\pwax1s.mpg
# 1/1 [==============================] - 1s 803ms/step
# complete_data\s5\pgwe5a.mpg
# 1/1 [==============================] - 1s 829ms/step
# complete_data\s5\sgbpzn.mpg
# 1/1 [==============================] - 1s 806ms/step
# complete_data\s5\sbim4n.mpg
# 1/1 [==============================] - 1s 852ms/step
# complete_data\s5\pbwp4p.mpg
# 1/1 [==============================] - 1s 805ms/step
# complete_data\s5\pwiv8p.mpg
# 1/1 [==============================] - 1s 795ms/step
# complete_data\s5\lgbl9s.mpg
# 1/1 [==============================] - 1s 824ms/step
# complete_data\s5\prio6n.mpg
# 1/1 [==============================] - 1s 820ms/step
# complete_data\s5\lbip9a.mpg
# 1/1 [==============================] - 1s 807ms/step
# complete_data\s5\lraq7s.mpg
# 1/1 [==============================] - 1s 793ms/step
# complete_data\s5\pgaj8n.mpg
# 1/1 [==============================] - 1s 837ms/step
# complete_data\s5\swwo9s.mpg
# 1/1 [==============================] - 1s 814ms/step
# complete_data\s5\pgwe4p.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\swih5a.mpg
# 1/1 [==============================] - 1s 812ms/step
# complete_data\s5\sgao8p.mpg
# 1/1 [==============================] - 1s 789ms/step
# complete_data\s5\bwim3a.mpg
# 1/1 [==============================] - 1s 866ms/step
# complete_data\s5\sgwc8p.mpg
# 1/1 [==============================] - 1s 822ms/step
# complete_data\s5\lgaz3s.mpg
# 1/1 [==============================] - 1s 828ms/step
# complete_data\s5\pgbd8n.mpg
# 1/1 [==============================] - 1s 798ms/step
# complete_data\s5\sgaczp.mpg
# 1/1 [==============================] - 1s 841ms/step
# complete_data\s5\bgba8p.mpg
# 1/1 [==============================] - 1s 837ms/step
# complete_data\s5\sbaa2p.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\sbwu1s.mpg
# 1/1 [==============================] - 1s 796ms/step
# complete_data\s5\bwwt7s.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\sgwc9a.mpg
# 1/1 [==============================] - 1s 820ms/step
# complete_data\s5\swwv3s.mpg
# 1/1 [==============================] - 1s 798ms/step
# complete_data\s5\swwc3a.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\lrwe6n.mpg
# 1/1 [==============================] - 1s 809ms/step
# complete_data\s5\pbwi8n.mpg
# 1/1 [==============================] - 1s 798ms/step
# complete_data\s5\prwx3s.mpg
# 1/1 [==============================] - 1s 829ms/step
# complete_data\s5\swao1s.mpg
# 1/1 [==============================] - 1s 787ms/step
# complete_data\s5\pbwc6p.mpg
# 1/1 [==============================] - 1s 811ms/step
# complete_data\s5\pbbc1s.mpg
# 1/1 [==============================] - 1s 815ms/step
# complete_data\s5\pbav1a.mpg
# 1/1 [==============================] - 1s 813ms/step
# complete_data\s5\pgwk8p.mpg
# 1/1 [==============================] - 1s 925ms/step
# complete_data\s5\sbwn9a.mpg
# 1/1 [==============================] - 1s 840ms/step
# complete_data\s5\lwbfzp.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\pbao6p.mpg
# 1/1 [==============================] - 1s 820ms/step
# complete_data\s5\srig8p.mpg
# 1/1 [==============================] - 1s 788ms/step
# complete_data\s5\bril4n.mpg
# 1/1 [==============================] - 1s 831ms/step
# complete_data\s5\bbwm1s.mpg
# 1/1 [==============================] - 1s 810ms/step
# complete_data\s5\pbao4n.mpg
# 1/1 [==============================] - 1s 823ms/step
# complete_data\s5\bbbszn.mpg
# 1/1 [==============================] - 1s 807ms/step
# complete_data\s5\lwiy5a.mpg
# 1/1 [==============================] - 1s 809ms/step
# complete_data\s5\sbwu2p.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\swbo4n.mpg
# 1/1 [==============================] - 1s 796ms/step
# complete_data\s5\pwbj7s.mpg
# 1/1 [==============================] - 1s 800ms/step
# complete_data\s5\prbj2p.mpg
# 1/1 [==============================] - 1s 800ms/step
# complete_data\s5\sgai2n.mpg
# 1/1 [==============================] - 1s 785ms/step
# complete_data\s5\srit4n.mpg
# 1/1 [==============================] - 1s 850ms/step
# complete_data\s5\lwbe9s.mpg
# 1/1 [==============================] - 1s 800ms/step
# complete_data\s5\bgwu3s.mpg
# 1/1 [==============================] - 1s 818ms/step
# complete_data\s5\bbik8n.mpg
# 1/1 [==============================] - 1s 779ms/step
# complete_data\s5\lwir1a.mpg
# 1/1 [==============================] - 1s 831ms/step
# complete_data\s5\bwwn3s.mpg
# 1/1 [==============================] - 1s 807ms/step
# complete_data\s5\bwwt9a.mpg
# 1/1 [==============================] - 1s 887ms/step
# complete_data\s5\pgix3s.mpg
# 1/1 [==============================] - 1s 809ms/step
# complete_data\s5\lgwm3s.mpg
# 1/1 [==============================] - 1s 797ms/step
# complete_data\s5\lrwl3a.mpg
# 1/1 [==============================] - 1s 826ms/step
# complete_data\s5\lrbe3s.mpg
# 1/1 [==============================] - 1s 824ms/step
# complete_data\s5\bgbh1s.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\pwip2n.mpg
# 1/1 [==============================] - 1s 791ms/step
# complete_data\s5\lwbl2n.mpg
# 1/1 [==============================] - 1s 833ms/step
# complete_data\s5\lray2p.mpg
# 1/1 [==============================] - 1s 822ms/step
# complete_data\s5\prwq1a.mpg
# 1/1 [==============================] - 1s 796ms/step
# complete_data\s5\bwba2p.mpg
# 1/1 [==============================] - 1s 804ms/step
# complete_data\s5\sbim5s.mpg
# 1/1 [==============================] - 1s 804ms/step
# b'.\\complete_data\\s5\\sbim5s.mpg'  :  set blue in i s rie seain  :  set blue in m five soon  :  50.0
# complete_data\s5\bgit2p.mpg
# 1/1 [==============================] - 1s 860ms/step
# complete_data\s5\pgakzp.mpg
# 1/1 [==============================] - 1s 790ms/step
# complete_data\s5\lwae7a.mpg
# 1/1 [==============================] - 1s 803ms/step
# complete_data\s5\brifzn.mpg
# 1/1 [==============================] - 1s 784ms/step
# complete_data\s5\braz7s.mpg
# 1/1 [==============================] - 1s 833ms/step
# complete_data\s5\braz8p.mpg
# 1/1 [==============================] - 1s 831ms/step
# complete_data\s5\bwbm8n.mpg
# 1/1 [==============================] - 1s 909ms/step
# complete_data\s5\bbbs2p.mpg
# 1/1 [==============================] - 1s 855ms/step
# complete_data\s5\bwwt8p.mpg
# 1/1 [==============================] - 1s 810ms/step
# complete_data\s5\swin8p.mpg
# 1/1 [==============================] - 1s 829ms/step
# complete_data\s5\lwwf3s.mpg
# 1/1 [==============================] - 1s 955ms/step
# complete_data\s5\pwwq6p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\brbs9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgit3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgbt8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lbidzp.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pwwx8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgwu4p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swwc1s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbao5s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sbis8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sbwn6n.mpg
# 1/1 [==============================] - 1s 995ms/step
# complete_data\s5\lgws7s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgwp5s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\braz6n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bbazzn.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swwpzp.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lgal7a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\prav7a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgwv9s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lrby4n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sbim7a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swwp1a.mpg
# 1/1 [==============================] - 1s 1000ms/step
# complete_data\s5\sbba4n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sbwh3s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\srwu9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bwas9s.mpg
# 1/1 [==============================] - 1s 964ms/step
# complete_data\s5\prbc9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgbi7s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pgax8p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgav2p.mpg
# 1/1 [==============================] - 1s 993ms/step
# complete_data\s5\pwwk3a.mpg
# 1/1 [==============================] - 1s 1000ms/step
# complete_data\s5\bgwo1a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbai3a.mpg
# 1/1 [==============================] - 1s 988ms/step
# complete_data\s5\bwbm9s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swin6n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pwbd4p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swab3s.mpg
# 1/1 [==============================] - 1s 978ms/step
# complete_data\s5\prwd3a.mpg
# 1/1 [==============================] - 1s 998ms/step
# complete_data\s5\sgao9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbib4p.mpg
# 1/1 [==============================] - 1s 979ms/step
# complete_data\s5\bbiy8p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bbar8p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\prbp4n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\prbj3a.mpg
# 1/1 [==============================] - 1s 978ms/step
# complete_data\s5\lrwlzn.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\srbn8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pwip4p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbiozn.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lbbk2p.mpg
# 1/1 [==============================] - 1s 991ms/step
# complete_data\s5\lwbz1s.mpg
# 1/1 [==============================] - 1s 973ms/step
# complete_data\s5\srig9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sbbhzp.mpg
# 1/1 [==============================] - 1s 999ms/step
# complete_data\s5\brwm7s.mpg
# 1/1 [==============================] - 1s 984ms/step
# complete_data\s5\lrbk8p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swwo8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lwwz4n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\srbozp.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbao7a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbbc3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgwp6p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swaozn.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgav1s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lgas1a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\priv2p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\brwm9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pwax3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sbwb1a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sgbv4n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lwwszn.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lrad8n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lgie9a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\brwg2n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sgio4p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbwn7s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pwbd2n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\brbg1a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\brwm8p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lraq6n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\swia8n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\brif3a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pwic6p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pgbq6n.mpg
# 1/1 [==============================] - 1s 931ms/step
# complete_data\s5\lwak9s.mpg
# 1/1 [==============================] - 1s 980ms/step
# complete_data\s5\bwif8p.mpg
# 1/1 [==============================] - 1s 865ms/step
# complete_data\s5\swib1a.mpg
# 1/1 [==============================] - 1s 875ms/step
# complete_data\s5\lgws8p.mpg
# 1/1 [==============================] - 1s 867ms/step
# complete_data\s5\bwis4n.mpg
# 1/1 [==============================] - 1s 838ms/step
# complete_data\s5\pbbo9s.mpg
# 1/1 [==============================] - 1s 893ms/step
# complete_data\s5\bril7a.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\sgbp3a.mpg
# 1/1 [==============================] - 1s 804ms/step
# complete_data\s5\pbbi5s.mpg
# 1/1 [==============================] - 1s 791ms/step
# complete_data\s5\bbbl6n.mpg
# 1/1 [==============================] - 1s 854ms/step
# complete_data\s5\bwis6p.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\bwimzn.mpg
# 1/1 [==============================] - 1s 796ms/step
# complete_data\s5\bwwhzp.mpg
# 1/1 [==============================] - 1s 811ms/step
# complete_data\s5\pgwr2p.mpg
# 1/1 [==============================] - 1s 926ms/step
# complete_data\s5\sbwh4p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lrby5s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lwiq8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bwag3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgav3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swah7s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgim8p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pwwk2p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\brwg4p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pgbq7s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgan1s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lrix7s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lrwr6p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swia9s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lwbzzn.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lbij2n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\brwg3s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pwwd6n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lwws3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgag7s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\prac4p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lrak3s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgim9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pgid3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lbip6n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\srwb4n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pgbq8p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbai2p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bbaz1s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pgax7s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgig5a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pwac9s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbib5a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lrwy9s.mpg
# 1/1 [==============================] - 1s 967ms/step
# complete_data\s5\briz2n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swbizn.mpg
# 1/1 [==============================] - 1s 995ms/step
# complete_data\s5\lgaszp.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swbu8n.mpg
# 1/1 [==============================] - 1s 999ms/step
# complete_data\s5\bbie4n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lgaz5a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgaa3s.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s5\\bgaa3s.mpg'  :  set green at v ive soon  :  bin green at a three soon  :  50.0
# complete_data\s5\sbaa3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lwie2p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lgiz1a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bbir3s.mpg
# 1/1 [==============================] - 1s 988ms/step
# b'.\\complete_data\\s5\\bbir3s.mpg'  :  bin blue in sire sgeain  :  bin blue in r three soon  :  50.0
# complete_data\s5\pgax6n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swwv2n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\prio9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\prii4p.mpg
# 1/1 [==============================] - 1s 959ms/step
# complete_data\s5\pbio2p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swiu2p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lgiy8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\prai6n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lgiy9s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgat6p.mpg
# 1/1 [==============================] - 1s 989ms/step
# complete_data\s5\swwi5s.mpg
# 1/1 [==============================] - 1s 986ms/step
# complete_data\s5\lwbr8p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgat7a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\braf6p.mpg
# 1/1 [==============================] - 1s 988ms/step
# complete_data\s5\pgwy5s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lbwe3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bwbazn.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\prac2n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgiu9a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbau8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sbitzp.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bbws5s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bbbf3s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bgwh5s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lrak2n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bbbz6p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\srat9s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pgby2p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\srwo3s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pgwrzn.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbbg9s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lrby7a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bgbn5s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pgaj9s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bwbg6p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bbbf5a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lwiq9s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\srau1a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bwim2p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pgij4n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bral9s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\priczp.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swau4n.mpg
# 1/1 [==============================] - 1s 874ms/step
# complete_data\s5\srwo2n.mpg
# 1/1 [==============================] - 1s 891ms/step
# complete_data\s5\pric1a.mpg
# 1/1 [==============================] - 1s 926ms/step
# complete_data\s5\srahzn.mpg
# 1/1 [==============================] - 1s 967ms/step
# complete_data\s5\lwbe8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lriq5a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\swwi4n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\srbb3a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lrbk9a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bbar9a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bgwh4n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pgad6p.mpg
# 1/1 [==============================] - 1s 797ms/step
# complete_data\s5\sgwc7s.mpg
# 1/1 [==============================] - 1s 801ms/step
# complete_data\s5\pbwc4n.mpg
# 1/1 [==============================] - 1s 828ms/step
# complete_data\s5\sbbt9a.mpg
# 1/1 [==============================] - 1s 819ms/step
# complete_data\s5\swiu3a.mpg
# 1/1 [==============================] - 1s 849ms/step
# complete_data\s5\bras2n.mpg
# 1/1 [==============================] - 1s 850ms/step
# complete_data\s5\bgwbzn.mpg
# 1/1 [==============================] - 1s 819ms/step
# complete_data\s5\lbaj7s.mpg
# 1/1 [==============================] - 1s 836ms/step
# complete_data\s5\pgid1s.mpg
# 1/1 [==============================] - 1s 824ms/step
# complete_data\s5\brwa1a.mpg
# 1/1 [==============================] - 1s 877ms/step
# complete_data\s5\bwis7a.mpg
# 1/1 [==============================] - 1s 781ms/step
# complete_data\s5\bgag9a.mpg
# 1/1 [==============================] - 1s 847ms/step
# complete_data\s5\pbwjzp.mpg
# 1/1 [==============================] - 1s 820ms/step
# complete_data\s5\prii3s.mpg
# 1/1 [==============================] - 1s 858ms/step
# complete_data\s5\lgbz7s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bbal5a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lbic9s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lgaf2p.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pbih6n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sbbg8n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sria5a.mpg
# 1/1 [==============================] - 1s 1s/step
# b'.\\complete_data\\s5\\sria5a.mpg'  :  set gren in n ninen again  :  set red in a five again  :  50.0
# complete_data\s5\sgbi6n.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lbwy5a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\bwwg9s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\pwbx5s.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\lwal1a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\sgwp7a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swbo7a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\brbgzp.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bwas8n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pgwr3a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sgwv8n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbwu3a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\prbxzp.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lrbrzn.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\bgba6n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\swab5a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\prbjzn.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pbio1s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sgac1a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pwwq7a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pgwy6p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lwbz2p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\srwu8p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\prac3s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sgab9s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\srig6n.mpg
# 1/1 [==============================] - 2s 2s/step
# b'.\\complete_data\\s5\\srig6n.mpg'  :  set green in g five soon  :  set red in g six now  :  50.0
# complete_data\s5\sbba6p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sria2n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\prwdzn.mpg
# 1/1 [==============================] - 1s 852ms/step
# complete_data\s5\lrij8n.mpg
# 1/1 [==============================] - 1s 925ms/step
# complete_data\s5\lbbd6n.mpg
# 1/1 [==============================] - 1s 815ms/step
# complete_data\s5\sbat5a.mpg
# 1/1 [==============================] - 1s 850ms/step
# complete_data\s5\srin3a.mpg
# 1/1 [==============================] - 1s 1s/step
# complete_data\s5\swih4p.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pbio3a.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\lwik4n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pwwd7s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbag5s.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\pbbi4n.mpg
# 1/1 [==============================] - 2s 2s/step
# complete_data\s5\sbaazn.mpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 14
#       9 for i in fl:
#      10     # print(str(i.decode('utf-8')))
#      11     # sample = load_data(tf.convert_to_tensor('.\\s2_pwaq2a.mpg'))
#      12     sample = load_data(tf.convert_to_tensor(i))
# ---> 14     yhat = model.predict(tf.expand_dims(sample[0], axis=0))
#      16     decoded = tf.keras.backend.ctc_decode(yhat, input_length=[75], greedy=True)[0][0].numpy()
#      18     predicted = [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in decoded][0].numpy().decode('utf-8')
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\keras\engine\training.py:2253, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2251 for step in data_handler.steps():
#    2252     callbacks.on_predict_batch_begin(step)
# -> 2253     tmp_batch_outputs = self.predict_function(iterator)
#    2254     if data_handler.should_sync:
#    2255         context.async_wait()
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\kires\anaconda3\envs\diff2lip\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
print('~'*100, 'PREDICTIONS')
predicted = [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in decoded][0].numpy().decode('utf-8')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ PREDICTIONS
# 'set green it r seve sgin'

# %%
model.reset_states()
